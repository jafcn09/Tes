# %%
#conectandose a google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#libreria de pandas implementada
import pandas as pd
from google.colab import data_table
from vega_datasets import data

# %%
# !pip install --upgrade google-colab

# %%
#llamando a la ruta
bancoNacion = '/content/drive/MyDrive/Trabajo_Grupo03/data/Peru.csv'

bancoNoruega2 = '/content/drive/MyDrive/Trabajo_Grupo03/data/Noruega2.csv'

# %%
#Declarando la variable en formado read_csv
df_banconac = pd.read_csv(bancoNacion, sep= ';', encoding='latin1')

# %%
data_table.enable_dataframe_formatter()

# %%
#Imprimiendo
df_banconac.head()
# Out:
#    FECHA_CORTE DEPARTAMENTO PROVINCIA DISTRITO  UBIGEO SEDE    CANAL  \
# 0     20230515          NaN       NaN      NaN     NaN  NaN  VIRTUAL
# 1     20230515          NaN       NaN      NaN     NaN  NaN  VIRTUAL
# 2     20230515          NaN       NaN      NaN     NaN  NaN  VIRTUAL
# 3     20230515          NaN       NaN      NaN     NaN  NaN  VIRTUAL
# 4     20230515          NaN       NaN      NaN     NaN  NaN  VIRTUAL
#
#    FECHA_INGRESO CODIGO_TRAMITE     TIPO_PERSONA    GENERO  FECHA_ATENCION   \
# 0       20220104       001-2022  PERSONA NATURAL  FEMENINO         20220114
# 1       20220105       002-2022  PERSONA NATURAL  FEMENINO         20220117
# 2       20220105       003-2022  PERSONA NATURAL  FEMENINO         20220110
# 3       20220105       004-2022  PERSONA NATURAL  FEMENINO         20220119
# 4       20220105       005-2022  PERSONA NATURAL  FEMENINO         20220119
#
#                                            CATEGORIA  PERIODO_ATENCION
# ...

# %%
df_banco_noruega2 = pd.read_csv(bancoNoruega2, sep=',')

# %%
df_banco_noruega2.reset_index(drop=True, inplace=True)

# %%
df_banco_noruega2
# Out:
#                                         Classification  \
# 0                                              Revenue
# 1                                              Revenue
# 2                                              Revenue
# 3                                              Revenue
# 4                                              Revenue
# ..                                                 ...
# 554  Unrealized mark-to market (losses) gains on in...
# 555  Unrealized mark-to market (losses) gains on no...
# 556  Unrealized mark-to market (losses) gains on no...
# 557                                           Subtotal
# 558                                  Net Income (Loss)
#
#                                               Grouping  \
# 0                                     Interest Revenue
# 1                                     Interest Revenue
# 2                                     Interest Revenue
# 3                                     Interest Revenue
# ...

# %% [markdown]
# # Preprocesamiento de banco noruega

# %%
#trayendo la información
df_banco_noruega2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Classification          559 non-null    object
#  1   Grouping                559 non-null    object
#  2   Category                559 non-null    object
#  3   Line Item Description   559 non-null    object
#  4   Year                    559 non-null    object
#  5   Amount (US$, Millions)  559 non-null    float64
# dtypes: float64(1), object(5)
# memory usage: 26.3+ KB

# %%
#eliminando tabla duplicadas
columnas_irrelevantes = ['Category', 'Line Item Description']
df_prebanco_noruega = df_banco_noruega2.drop(columnas_irrelevantes, axis=1)

# %%
#imprimiendo la tablas
df_prebanco_noruega.head()
# Out:
#   Classification          Grouping                    Year  \
# 0        Revenue  Interest Revenue  06/30/2014 12:00:00 AM
# 1        Revenue  Interest Revenue  06/30/2013 12:00:00 AM
# 2        Revenue  Interest Revenue  06/30/2012 12:00:00 AM
# 3        Revenue  Interest Revenue  06/30/2011 12:00:00 AM
# 4        Revenue  Interest Revenue  06/30/2010 12:00:00 AM
#
#    Amount (US$, Millions)
# 0                  1012.0
# 1                  1019.0
# 2                   912.0
# 3                   895.0
# 4                   835.0

# %%
df_prebanco_noruega.dropna(inplace = True)

# %%
df_prebanco_noruega.drop_duplicates()
# Out:
#                                         Classification  \
# 0                                              Revenue
# 1                                              Revenue
# 2                                              Revenue
# 3                                              Revenue
# 4                                              Revenue
# ..                                                 ...
# 554  Unrealized mark-to market (losses) gains on in...
# 555  Unrealized mark-to market (losses) gains on no...
# 556  Unrealized mark-to market (losses) gains on no...
# 557                                           Subtotal
# 558                                  Net Income (Loss)
#
#                                               Grouping  \
# 0                                     Interest Revenue
# 1                                     Interest Revenue
# 2                                     Interest Revenue
# 3                                     Interest Revenue
# ...

# %%
df_prebanco_noruega['PERIODO'] = df_prebanco_noruega['Year'].astype(str).str[:6]
df_prebanco_noruega
# Out:
#                                         Classification  \
# 0                                              Revenue
# 1                                              Revenue
# 2                                              Revenue
# 3                                              Revenue
# 4                                              Revenue
# ..                                                 ...
# 554  Unrealized mark-to market (losses) gains on in...
# 555  Unrealized mark-to market (losses) gains on no...
# 556  Unrealized mark-to market (losses) gains on no...
# 557                                           Subtotal
# 558                                  Net Income (Loss)
#
#                                               Grouping  \
# 0                                     Interest Revenue
# 1                                     Interest Revenue
# 2                                     Interest Revenue
# 3                                     Interest Revenue
# ...

# %%
df_prebanco_noruega
# Out:
#                                         Classification  \
# 0                                              Revenue
# 1                                              Revenue
# 2                                              Revenue
# 3                                              Revenue
# 4                                              Revenue
# ..                                                 ...
# 554  Unrealized mark-to market (losses) gains on in...
# 555  Unrealized mark-to market (losses) gains on no...
# 556  Unrealized mark-to market (losses) gains on no...
# 557                                           Subtotal
# 558                                  Net Income (Loss)
#
#                                               Grouping  \
# 0                                     Interest Revenue
# 1                                     Interest Revenue
# 2                                     Interest Revenue
# 3                                     Interest Revenue
# ...

# %%
df_prebanco_noruega.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Classification          559 non-null    object
#  1   Grouping                559 non-null    object
#  2   Year                    559 non-null    object
#  3   Amount (US$, Millions)  559 non-null    float64
#  4   PERIODO                 559 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 22.0+ KB

# %% [markdown]
# # Preprocesamiento de banco de la nacion de Perú

# %%
#mostrando info de la tablas
df_banconac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387 entries, 0 to 386
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FECHA_CORTE       387 non-null    int64
#  1   DEPARTAMENTO      92 non-null     object
#  2   PROVINCIA         92 non-null     object
#  3   DISTRITO          92 non-null     object
#  4   UBIGEO            92 non-null     float64
#  5   SEDE              92 non-null     object
#  6   CANAL             387 non-null    object
#  7   FECHA_INGRESO     387 non-null    int64
#  8   CODIGO_TRAMITE    387 non-null    object
#  9   TIPO_PERSONA      387 non-null    object
#  10  GENERO            387 non-null    object
#  11  FECHA_ATENCION    387 non-null    int64
#  12  CATEGORIA         387 non-null    object
#  13  PERIODO_ATENCION  387 non-null    int64
# dtypes: float64(1), int64(4), object(9)
# memory usage: 42.5+ KB

# %%
#eliminando tabla duplicadas
excluyendo = ['DISTRITO', 'SEDE', 'TIPO_PERSONA']
df_prebanco_peru = df_banconac.drop(excluyendo, axis=1)

# %%
#imprimiendo la tablas
df_prebanco_peru.head()
# Out:
#    FECHA_CORTE DEPARTAMENTO PROVINCIA  UBIGEO    CANAL  FECHA_INGRESO  \
# 0     20230515          NaN       NaN     NaN  VIRTUAL       20220104
# 1     20230515          NaN       NaN     NaN  VIRTUAL       20220105
# 2     20230515          NaN       NaN     NaN  VIRTUAL       20220105
# 3     20230515          NaN       NaN     NaN  VIRTUAL       20220105
# 4     20230515          NaN       NaN     NaN  VIRTUAL       20220105
#
#   CODIGO_TRAMITE    GENERO  FECHA_ATENCION   \
# 0       001-2022  FEMENINO         20220114
# 1       002-2022  FEMENINO         20220117
# 2       003-2022  FEMENINO         20220110
# 3       004-2022  FEMENINO         20220119
# 4       005-2022  FEMENINO         20220119
#
#                                            CATEGORIA  PERIODO_ATENCION
# 0  INFORMACIÓN PRODUCIDA EXCLUSIVAMENTE RELACIONA...          20220114
# 1                                  SOBRE EL PERSONAL          20220117
# ...

# %%
df_prebanco_peru.head()
# Out:
#    FECHA_CORTE DEPARTAMENTO PROVINCIA  UBIGEO    CANAL  FECHA_INGRESO  \
# 0     20230515          NaN       NaN     NaN  VIRTUAL       20220104
# 1     20230515          NaN       NaN     NaN  VIRTUAL       20220105
# 2     20230515          NaN       NaN     NaN  VIRTUAL       20220105
# 3     20230515          NaN       NaN     NaN  VIRTUAL       20220105
# 4     20230515          NaN       NaN     NaN  VIRTUAL       20220105
#
#   CODIGO_TRAMITE    GENERO  FECHA_ATENCION   \
# 0       001-2022  FEMENINO         20220114
# 1       002-2022  FEMENINO         20220117
# 2       003-2022  FEMENINO         20220110
# 3       004-2022  FEMENINO         20220119
# 4       005-2022  FEMENINO         20220119
#
#                                            CATEGORIA  PERIODO_ATENCION
# 0  INFORMACIÓN PRODUCIDA EXCLUSIVAMENTE RELACIONA...          20220114
# 1                                  SOBRE EL PERSONAL          20220117
# ...

# %%
df_prebanco_peru.dropna(inplace = True)

# %%
df_prebanco_peru.drop_duplicates()
# Out:
#      FECHA_CORTE DEPARTAMENTO PROVINCIA    UBIGEO       CANAL  FECHA_INGRESO  \
# 14      20230515         LIMA      LIMA  150130.0  PRESENCIAL       20220114
# 17      20230515         LIMA      LIMA  150130.0  PRESENCIAL       20220119
# 19      20230515         LIMA      LIMA  150130.0  PRESENCIAL       20220124
# 20      20230515         LIMA      LIMA  150130.0  PRESENCIAL       20220125
# 23      20230515         LIMA      LIMA  150130.0  PRESENCIAL       20220201
# ..           ...          ...       ...       ...         ...            ...
# 381     20230515     AREQUIPA     ISLAY   40701.0  PRESENCIAL       20220429
# 382     20230515        TACNA     TACNA  230101.0  PRESENCIAL       20220921
# 383     20230515        TACNA     TACNA  230101.0  PRESENCIAL       20220929
# 384     20230515     AREQUIPA  AREQUIPA   40101.0  PRESENCIAL       20220820
# 385     20230515     AREQUIPA     ISLAY   40701.0  PRESENCIAL       20220601
#
# ...

# %%
df_prebanco_peru['Tiempo'] = df_prebanco_peru['FECHA_INGRESO'].astype(str).str[:6]
df_prebanco_peru
# Out:
#      FECHA_CORTE DEPARTAMENTO PROVINCIA    UBIGEO       CANAL  FECHA_INGRESO  \
# 14      20230515         LIMA      LIMA  150130.0  PRESENCIAL       20220114
# 17      20230515         LIMA      LIMA  150130.0  PRESENCIAL       20220119
# 19      20230515         LIMA      LIMA  150130.0  PRESENCIAL       20220124
# 20      20230515         LIMA      LIMA  150130.0  PRESENCIAL       20220125
# 23      20230515         LIMA      LIMA  150130.0  PRESENCIAL       20220201
# ..           ...          ...       ...       ...         ...            ...
# 381     20230515     AREQUIPA     ISLAY   40701.0  PRESENCIAL       20220429
# 382     20230515        TACNA     TACNA  230101.0  PRESENCIAL       20220921
# 383     20230515        TACNA     TACNA  230101.0  PRESENCIAL       20220929
# 384     20230515     AREQUIPA  AREQUIPA   40101.0  PRESENCIAL       20220820
# 385     20230515     AREQUIPA     ISLAY   40701.0  PRESENCIAL       20220601
#
# ...

# %%
df_prebanco_peru
# Out:
#      FECHA_CORTE DEPARTAMENTO PROVINCIA    UBIGEO       CANAL  FECHA_INGRESO  \
# 14      20230515         LIMA      LIMA  150130.0  PRESENCIAL       20220114
# 17      20230515         LIMA      LIMA  150130.0  PRESENCIAL       20220119
# 19      20230515         LIMA      LIMA  150130.0  PRESENCIAL       20220124
# 20      20230515         LIMA      LIMA  150130.0  PRESENCIAL       20220125
# 23      20230515         LIMA      LIMA  150130.0  PRESENCIAL       20220201
# ..           ...          ...       ...       ...         ...            ...
# 381     20230515     AREQUIPA     ISLAY   40701.0  PRESENCIAL       20220429
# 382     20230515        TACNA     TACNA  230101.0  PRESENCIAL       20220921
# 383     20230515        TACNA     TACNA  230101.0  PRESENCIAL       20220929
# 384     20230515     AREQUIPA  AREQUIPA   40101.0  PRESENCIAL       20220820
# 385     20230515     AREQUIPA     ISLAY   40701.0  PRESENCIAL       20220601
#
# ...

# %%
df_prebanco_peru.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 92 entries, 14 to 385
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FECHA_CORTE       92 non-null     int64
#  1   DEPARTAMENTO      92 non-null     object
#  2   PROVINCIA         92 non-null     object
#  3   UBIGEO            92 non-null     float64
#  4   CANAL             92 non-null     object
#  5   FECHA_INGRESO     92 non-null     int64
#  6   CODIGO_TRAMITE    92 non-null     object
#  7   GENERO            92 non-null     object
#  8   FECHA_ATENCION    92 non-null     int64
#  9   CATEGORIA         92 non-null     object
#  10  PERIODO_ATENCION  92 non-null     int64
#  11  Tiempo            92 non-null     object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 9.3+ KB

# %% [markdown]
# # EXPORTANDO CSV

# %%
df_prebanco_peru.to_csv('/content/drive/MyDrive/Trabajo_Grupo03/data/PreBancoPeru.csv', header=True, index=True, sep=',')

# %%
df_prebanco_noruega.to_csv('/content/drive/MyDrive/Trabajo_Grupo03/data/PreBancoNoruega.csv', header=True, index=True, sep=',')

# %% [markdown]
# # ENTRENAMIENTO DEL MODELO

# %%
prebanco_noruega = '/content/drive/MyDrive/Trabajo_Grupo03/data/PreBancoNoruega.csv'

# %%
prebanco_peru = '/content/drive/MyDrive/Trabajo_Grupo03/data/PreBancoPeru.csv'

# %%
en_prebanco_peru = pd.read_csv(prebanco_peru, sep=',')

# %%
en_prebanco_noruega = pd.read_csv(prebanco_noruega, sep=',')

# %%
en_prebanco_peru['FECHA_INGRESO'] = [1 for i in range(len(en_prebanco_peru))]

# %%
print(en_prebanco_noruega.columns)
# Out:
# Index(['Unnamed: 0', 'Classification', 'Grouping', 'Year',
#        'Amount (US$, Millions)', 'PERIODO'],
#       dtype='object')

# %%
print(en_prebanco_peru.columns)
# Out:
# Index(['Unnamed: 0', 'FECHA_CORTE', 'DEPARTAMENTO', 'PROVINCIA', 'UBIGEO',
#        'CANAL', 'FECHA_INGRESO', 'CODIGO_TRAMITE', 'GENERO', 'FECHA_ATENCION ',
#        'CATEGORIA', 'PERIODO_ATENCION', 'Tiempo'],
#       dtype='object')

# %%
en_prebanco_noruega['Classification'] = [1 for i in range(len(en_prebanco_noruega))]
